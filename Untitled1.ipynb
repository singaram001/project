# %% [markdown]
# <a href="https://colab.research.google.com/github/singaram001/project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import pandas as pd
import numpy as np

# Import Visualization Libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Dataset from github repository
url = 'https://raw.githubusercontent.com/yahya-ansariii/TelecomChurnEDA/master/Telecom%20Churn.csv'
data = pd.read_csv(url)

# %%
# View top 5 rows of the dataset
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
# View last 5 rows of the dataset
data.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False

# %%
# Checking number of rows and columns of the dataset using shape
print("Number of rows are: ",data.shape[0])
print("Number of columns are: ",data.shape[1])
# Out:
# Number of rows are:  3333
# Number of columns are:  20

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(data.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# Dataset Columns
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Dataset Columns
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
### Variables Description

# %%
# Before doing any data wrangling lets create copy of the dataset
data_2 = data.copy()

# %%
# Check for how many customer leave the company (Churn)
churn = pd.DataFrame(data_2['Churn'].value_counts())
churn['Churn Rate'] = round(churn*100/len(data_2),2)
churn
# Out:
#        count  Churn Rate
# Churn
# False   2850       85.51
# True     483       14.49

# %%
# Lets check churn rate area code wise
churn_area = pd.DataFrame(data_2.groupby('Area code')['Churn'].value_counts())
churn_area['churn rate'] = round(churn_area*100/len(data_2),2)
churn_area
# Out:
#                  count  churn rate
# Area code Churn
# 408       False    716       21.48
#           True     122        3.66
# 415       False   1419       42.57
#           True     236        7.08
# 510       False    715       21.45
#           True     125        3.75

# %%
#Lets check the statistical value(mean, median) of all feature of area code wise
def get_mean_median(data,area_code):
  ''' This fuction gives mean and median of all features'''
  try:
    return pd.concat([data_2[data_2['Area code']==area_code].describe().round(2).iloc[1],
          data_2[data_2['Area code']==area_code].describe().round(2).iloc[5]], axis = 1).rename(columns={'50%':'Median'})
  except:
    print("Invalid Area code")

# %%
# For areacode 408
get_mean_median(data_2,408)
# Out:
#                           mean  Median
# Account length          101.88  102.00
# Area code               408.00  408.00
# Number vmail messages     7.67    0.00
# Total day minutes       177.18  176.35
# Total day calls         100.50  100.00
# Total day charge         30.12   29.98
# Total eve minutes       201.28  202.50
# Total eve calls          99.79   99.00
# Total eve charge         17.11   17.21
# Total night minutes     199.21  199.55
# Total night calls        99.04  100.00
# Total night charge        8.96    8.98
# Total intl minutes       10.13   10.10
# Total intl calls          4.43    4.00
# Total intl charge         2.73    2.73
# Customer service calls    1.52    1.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Median'].plot(kind='hist', bins=20, title='Median')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='mean', y='Median', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['mean'].plot(kind='line', figsize=(8, 4), title='mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['Median'].plot(kind='line', figsize=(8, 4), title='Median')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#For areacode = 415
get_mean_median(data_2,415)
# Out:
#                           mean  Median
# Account length          101.07  100.00
# Area code               415.00  415.00
# Number vmail messages     8.36    0.00
# Total day minutes       181.59  180.70
# Total day calls         100.58  101.00
# Total day charge         30.87   30.72
# Total eve minutes       200.65  200.70
# Total eve calls         100.50  101.00
# Total eve charge         17.06   17.06
# Total night minutes     202.04  203.00
# Total night calls       100.40  101.00
# Total night charge        9.09    9.14
# Total intl minutes       10.34   10.50
# Total intl calls          4.56    4.00
# Total intl charge         2.79    2.84
# Customer service calls    1.55    1.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Median'].plot(kind='hist', bins=20, title='Median')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='mean', y='Median', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['mean'].plot(kind='line', figsize=(8, 4), title='mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Median'].plot(kind='line', figsize=(8, 4), title='Median')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#For areacode = 510
get_mean_median(data_2,510)
# Out:
#                           mean  Median
# Account length          100.25  100.00
# Area code               510.00  510.00
# Number vmail messages     8.02    0.00
# Total day minutes       178.79  179.45
# Total day calls         100.10  100.00
# Total day charge         30.39   30.51
# Total eve minutes       201.32  201.95
# Total eve calls          99.67  100.50
# Total eve charge         17.11   17.16
# Total night minutes     200.23  197.95
# Total night calls       100.60  100.00
# Total night charge        9.01    8.91
# Total intl minutes       10.14   10.20
# Total intl calls          4.37    4.00
# Total intl charge         2.74    2.75
# Customer service calls    1.62    1.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Median'].plot(kind='hist', bins=20, title='Median')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12.plot(kind='scatter', x='mean', y='Median', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['mean'].plot(kind='line', figsize=(8, 4), title='mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Median'].plot(kind='line', figsize=(8, 4), title='Median')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Churn count by statewise
churn_state = pd.DataFrame(data_2.groupby('State')['Churn'].value_counts()).rename(columns = {'Churn':'Count of Churn'})
churn_state
# Out:
#              count
# State Churn
# AK    False     49
#       True       3
# AL    False     72
#       True       8
# AR    False     44
# ...            ...
# WI    True       7
# WV    False     96
#       True      10
# WY    False     68
#       True       9
#
# [102 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# churn_state['count'].plot(kind='hist', bins=20, title='count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# churn_state['count'].plot(kind='line', figsize=(8, 4), title='count')
# plt.gca().spines[['top', 'right']].set_visible(False)
